# %%
import pandas as pd
import seaborn as sns
import sys
import os
from dotenv import load_dotenv
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestRegressor

sys.path.append(os.path.abspath('..'))
from helpers import feature_eng_helpers as fp, NUMERIC_COLS, CAT_COLS, TARGET_COL

# %%
load_dotenv()
train_cnt_0 = pd.read_csv(os.getenv("CLEAN_DATA_PATH") + "/" + "sales_train_cnt_0.csv")

# %%
x_train0, x_test0, y_train0, y_test0 = fp.preprocess_and_split_data(train_cnt_0)

# %%
x_train0.shape
# Out:
# (2055090, 8031)

# %%
rf0 = RandomForestRegressor(
    n_estimators=100, max_features="sqrt", n_jobs=-2, 
    min_samples_leaf=50, max_samples=0.75
    random_state=RAND_STATE
)
