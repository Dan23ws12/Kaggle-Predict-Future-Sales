# %%
import pandas as pd
import seaborn as sns
import os
import sys
from dotenv import load_dotenv
from sklearn.metrics import mean_squared_error as mse
from lightgbm import LGBMRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# Adds parent directory ('src/') to sys.path
sys.path.append(os.path.abspath('..'))
from helpers import feature_eng_helpers as fp, NUMERIC_COLS, CAT_COLS, TARGET_COL

# %%
load_dotenv()
train_cnt_0 = pd.read_csv(os.getenv("CLEAN_DATA_PATH") + "/" + "sales_train_cnt_0.csv")
train_cnt_abs = pd.read_csv(os.getenv("CLEAN_DATA_PATH") + "/" + "sales_train_cnt_abs.csv")
train_cnt_bfill = pd.read_csv(os.getenv("CLEAN_DATA_PATH") + "/" + "sales_train_cnt_bfill.csv")
train_cnt_ffill = pd.read_csv(os.getenv("CLEAN_DATA_PATH") + "/" + "sales_train_cnt_ffill.csv")
train_cnt_mean = pd.read_csv(os.getenv("CLEAN_DATA_PATH") + "/" + "sales_train_cnt_mean.csv")

# %% [markdown]
# TRAINING MODELS

# %%
x_train_0, x_test_0, y_train_0, y_test_0 = fp.split_data(train_cnt_0)

# %%
x_train_0.shape
# Out:
# (2055090, 21902)

# %%
train_cnt_0.head(2)
# Out:
#    month_block_num  shop_id  item_id  item_price  item_cnt_month
# 0                0       59    22154       999.0             1.0
# 1                0       25     2552       899.0             1.0
